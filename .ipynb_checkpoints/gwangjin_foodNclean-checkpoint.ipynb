# %%
import pandas as pd

df_food = pd.read_csv("gwangjin_food.csv")
df_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4605 entries, 0 to 4604
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   상호        4605 non-null   object
#  1   주소        4605 non-null   object
#  2   상권업종대분류명  4605 non-null   object
#  3   상권업종중분류명  4605 non-null   object
#  4   상권업종소분류명  4605 non-null   object
#  5   경도        4605 non-null   float64
#  6   위도        4605 non-null   float64
#  7   도로명주소     4605 non-null   object
# dtypes: float64(2), object(6)
# memory usage: 287.9+ KB

# %%
df_clean = pd.read_csv("위생등급업소_전처리.csv")
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   지정기관          187 non-null    object
#  1   지정일자          187 non-null    object
#  2   지정등급          187 non-null    object
#  3   업소명           187 non-null    object
#  4   영업자명          187 non-null    object
#  5   소재지(도로명)      187 non-null    object
#  6   업종명           187 non-null    object
#  7   법정동명(식품영업대장)  187 non-null    object
# dtypes: object(8)
# memory usage: 11.8+ KB

# %%
df_clean.head(30)
# Out:
#         지정기관        지정일자  지정등급                       업소명      영업자명  \
# 0   식품의약품안전처  2023-05-23  매우우수  (유)아웃백스테이크하우스코리아 건대스타시티점       박*종
# 1   식품의약품안전처  2024-08-09  매우우수           (주)핫시즈너동대문엽기떡볶이       금*일
# 2   식품의약품안전처  2024-04-15  매우우수                 60계 서울군자점       안*진
# 3   식품의약품안전처  2024-05-29  매우우수                  60계구의광장점       이*훈
# 4   식품의약품안전처  2023-08-20  매우우수                    BHC중곡점       조*미
# 5   식품의약품안전처  2024-07-01  매우우수              감탄떡볶이롯데마트강변점       김*주
# 6   식품의약품안전처  2023-06-15  매우우수                 고디바 롯데건대점  오*경 외 1명
# 7   식품의약품안전처  2024-05-14  매우우수                       고술행       박*일
# 8   식품의약품안전처  2023-07-18    우수                  교촌치킨 광장점  맹*권 외 1명
# 9   식품의약품안전처  2023-09-18  매우우수                교촌치킨(중곡2호)       장*혁
# 10  식품의약품안전처  2023-06-22    우수                 군자사랑파리바게뜨       신*자
# 11  식품의약품안전처  2023-02-24  매우우수                  굽네치킨중곡4동       박*선
# 12  식품의약품안전처  2023-06-15  매우우수                    그래인스쿠키       김*중
# ...

# %%
## 위생등급업소 업소명 공백 제거
df_clean['업소명'] = df_clean['업소명'].str.strip()
df_clean.head(30)
# Out:
#         지정기관        지정일자  지정등급                       업소명      영업자명  \
# 0   식품의약품안전처  2023-05-23  매우우수  (유)아웃백스테이크하우스코리아 건대스타시티점       박*종
# 1   식품의약품안전처  2024-08-09  매우우수           (주)핫시즈너동대문엽기떡볶이       금*일
# 2   식품의약품안전처  2024-04-15  매우우수                 60계 서울군자점       안*진
# 3   식품의약품안전처  2024-05-29  매우우수                  60계구의광장점       이*훈
# 4   식품의약품안전처  2023-08-20  매우우수                    BHC중곡점       조*미
# 5   식품의약품안전처  2024-07-01  매우우수              감탄떡볶이롯데마트강변점       김*주
# 6   식품의약품안전처  2023-06-15  매우우수                 고디바 롯데건대점  오*경 외 1명
# 7   식품의약품안전처  2024-05-14  매우우수                       고술행       박*일
# 8   식품의약품안전처  2023-07-18    우수                  교촌치킨 광장점  맹*권 외 1명
# 9   식품의약품안전처  2023-09-18  매우우수                교촌치킨(중곡2호)       장*혁
# 10  식품의약품안전처  2023-06-22    우수                 군자사랑파리바게뜨       신*자
# 11  식품의약품안전처  2023-02-24  매우우수                  굽네치킨중곡4동       박*선
# 12  식품의약품안전처  2023-06-15  매우우수                    그래인스쿠키       김*중
# ...

# %%
matched_data = df_food[df_food['상호'].isin(df_clean['업소명'])]

matched_data
# Out:
#                    상호                              주소 상권업종대분류명 상권업종중분류명  \
# 15              팔자좀피자    서울특별시 광진구 뚝섬로 509-1 (자양동) 1층       음식    기타 간이
# 34           래빗홀버거컴퍼니        서울특별시 광진구 광나루로 424 (화양동)       음식    기타 간이
# 374               한가람          서울특별시 광진구 능동로 92 (자양동)       음식       한식
# 448              열정국밥   서울특별시 광진구 아차산로55길 20 (구의동) 2층       음식       한식
# 536              뚜레쥬르   서울특별시 광진구 광나루로56길 29 (구의동) 1층       음식    기타 간이
# 682             던킨도너츠        서울특별시 광진구 아차산로 502 (광장동)       음식    기타 간이
# 687       베스킨라빈스광장현대점        서울특별시 광진구 아차산로 494 (광장동)       음식    기타 간이
# 763     배스킨라빈스건대동문회관점     서울특별시 광진구 아차산로 288 (자양동) 1층       음식    기타 간이
# 792               고술행    서울특별시 광진구 긴고랑로22길 4 (중곡동) 1층       음식       한식
# 876        옥루몽어린이대공원점      서울특별시 광진구 능동로 183 (화양동) 1층       음식    비알코올
# 1995           투썸플레이스      서울특별시 광진구 천호대로 642 (능동) 2층       음식    비알코올
# 2200             뚜레쥬르        서울특별시 광진구 아차산로 370 (자양동)       음식    기타 간이
# ...

# %%
df_food.merge(df_clean['업소명'], left_on="상호", right_on="업소명", how="left")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df_food['상호'].merge(df_clean['업소명'], left_on="상호", right_on="업소명", how="left")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'merge'
